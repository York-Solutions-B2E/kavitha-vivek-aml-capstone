# %%
 #Queries ran in big query console
    SELECT COUNT(DISTINCT(trafficSource.referralPath)) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;

 SELECT COUNT(trafficSource.campaign) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
  SELECT DISTINCT(trafficSource.campaign) as CAMP, COUNT(*) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP LIMIT 1000;
  SELECT COUNT(DISTINCT(trafficSource.campaign)) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;

 SELECT COUNT(trafficSource.source) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
 SELECT DISTINCT(trafficSource.source) as CAMP, COUNT(*) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP LIMIT 1000;
  SELECT COUNT(DISTINCT(trafficSource.source)) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;

SELECT COUNT(trafficSource.medium) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
SELECT DISTINCT(trafficSource.medium) as CAMP, COUNT(*) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP LIMIT 1000;

SELECT COUNT(trafficSource.keyword) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
#241905
SELECT DISTINCT(trafficSource.keyword) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
661748
2	
(not provided)
222542
3	
6qEhsCssdK0z36ri
4649
4	
google merchandise store
1834
5	
Google Merchandise
1399
6	
1hZbAqLCbjwfgOH7
1258
7	
(Remarketing/Content targeting)
886
8	
google store
845
9	
youtube
459
10	
1X4Me6ZKNV0zg-jV
297

SELECT COUNT(trafficSource.adContent) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
#10946
SELECT DISTINCT(trafficSource.adContent) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
892707
2	
Google Merchandise Collection
5122
3	
Google Online Store
1245
4	
Display Ad created 3/11/14
967
5	
Full auto ad IMAGE ONLY
822

SELECT COUNT(trafficSource.isTrueDirect) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
#274005
SELECT DISTINCT(trafficSource.isTrueDirect) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
629648
2	
true
274005

SELECT COUNT(trafficSource.campaignCode) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` LIMIT 1000;
#1
SELECT DISTINCT(trafficSource.campaignCode) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
Row	
CAMP
COUNT
1	
null
903652
2	
11251kjhkvahf
1

SELECT COUNT(trafficSource.adwordsClickInfo.campaignId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#0

SELECT COUNT(trafficSource.adwordsClickInfo.adGroupId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#0

SELECT COUNT(trafficSource.adwordsClickInfo.creativeId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#0

SELECT COUNT(trafficSource.adwordsClickInfo.criteriaId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#0

SELECT COUNT(trafficSource.adwordsClickInfo.page) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#21460
SELECT DISTINCT(trafficSource.adwordsClickInfo.page) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
882193
2	
1
21362
3	
2
73
4	
3
10

SELECT COUNT(trafficSource.adwordsClickInfo.slot) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#21460
SELECT DISTINCT(trafficSource.adwordsClickInfo.slot) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
882193
2	
Top
20956
3	
RHS
504

SELECT COUNT(trafficSource.adwordsClickInfo.criteriaParameters) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#903653
SELECT DISTINCT(trafficSource.adwordsClickInfo.criteriaParameters) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
not available in demo dataset
903653


SELECT COUNT(trafficSource.adwordsClickInfo.gclId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#21561
SELECT DISTINCT(trafficSource.adwordsClickInfo.gclId) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
Too many - max count is 70; mostly single digit counts 

SELECT COUNT(trafficSource.adwordsClickInfo.customerId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#0

SELECT COUNT(trafficSource.adwordsClickInfo.adNetworkType) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#21460
SELECT DISTINCT(trafficSource.adwordsClickInfo.adNetworkType) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
882193
2	
Google Search
21453
3	
Search partners
7


SELECT COUNT(trafficSource.adwordsClickInfo.isVideoAd) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#21460
SELECT DISTINCT(trafficSource.adwordsClickInfo.isVideoAd) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;
1	
null
882193
2	
false
21460

SELECT COUNT(trafficSource.adwordsClickInfo.targetingCriteria.boomUserListId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`;
#0
SELECT DISTINCT(trafficSource.adwordsClickInfo.targetingCriteria.boomUserListId) as CAMP, COUNT(*) as COUNT FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*` GROUP BY CAMP ORDER BY COUNT DESC LIMIT 100;

SELECT COUNT(promo.promoId) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo;
#5821491
SELECT DISTINCT(promo.promoId) AS temp, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo GROUP BY temp ORDER BY count DESC LIMIT 100;


SELECT COUNT(promo.promoName) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo;
#5821491
SELECT DISTINCT(promo.promoName) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(promo.promoCreative) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo;
#5821491
SELECT DISTINCT(promo.promoCreative) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo GROUP BY unique_value ORDER BY count DESC LIMIT 100;


SELECT COUNT(promo.promoPosition) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo;
#5821491
SELECT DISTINCT(promo.promoPosition) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.promotion) as promo GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.promotionActionInfo.promoIsView) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#622860
SELECT DISTINCT(h.promotionActionInfo.promoIsView) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;
1	
null
3530815
2	
true
622860

SELECT COUNT(h.promotionActionInfo.promoIsClick) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#53495
SELECT DISTINCT(h.promotionActionInfo.promoIsClick) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.eCommerceAction.action_type) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#4153675
SELECT DISTINCT(h.eCommerceAction.action_type) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;


SELECT COUNT(h.eCommerceAction.step) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#4153675
SELECT DISTINCT(h.eCommerceAction.step) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.eCommerceAction.option) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#87648
SELECT DISTINCT(h.eCommerceAction.option) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.page.pagePath) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#4153675
SELECT DISTINCT(h.page.pagePath) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.page.hostName) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#4153675
SELECT DISTINCT(h.page.hostName) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.page.pageTitle) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#4152819
SELECT DISTINCT(h.page.pageTitle) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.page.searchKeyword) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#833
SELECT DISTINCT(h.page.searchKeyword) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.page.searchCategory) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#873
SELECT DISTINCT(h.page.searchCategory) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;

SELECT COUNT(h.page.pagePathLevel4) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h;
#Level1 - 4153675
#Level2 - 4153675
#Level3 - 4153675
#Level4 - 4153675
SELECT DISTINCT(h.page.pagePathLevel4) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h GROUP BY unique_value ORDER BY count DESC LIMIT 100;


SELECT COUNT(p.productSKU) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h LEFT JOIN UNNEST(h.product) as p;
#18608748
SELECT COUNT(DISTINCT p.productSKU) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h LEFT JOIN UNNEST(h.product) as p; #1888
SELECT DISTINCT(p.productSKU) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.product) as p GROUP BY unique_value ORDER BY count DESC LIMIT 100;


SELECT COUNT(p.v2ProductCategory) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h LEFT JOIN UNNEST(h.product) as p;
#18608748
SELECT COUNT(DISTINCT p.v2ProductCategory) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h LEFT JOIN UNNEST(h.product) as p;
SELECT DISTINCT(p.v2ProductCategory) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.product) as p GROUP BY unique_value ORDER BY count DESC LIMIT 100;


SELECT COUNT(p.productPrice) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h LEFT JOIN UNNEST(h.product) as p;
#18608748
SELECT COUNT(DISTINCT p.productPrice) FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h LEFT JOIN UNNEST(h.product) as p;
SELECT DISTINCT(p.productPrice) AS unique_value, count(*) as count FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`, UNNEST(hits) as h, UNNEST(h.product) as p GROUP BY unique_value ORDER BY count DESC LIMIT 100;
